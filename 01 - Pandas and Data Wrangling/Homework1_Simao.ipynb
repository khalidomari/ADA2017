# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Task-1.-Compiling-Ebola-Data"><span class="toc-item-num">Task 1.&nbsp;&nbsp;</span>Compiling Ebola Data</a></div>
#  <div class="lev1"><a href="#Task-2.-RNA-Sequences"><span class="toc-item-num">Task 2.&nbsp;&nbsp;</span>RNA Sequences</a></div>
#  <div class="lev1"><a href="#Task-3.-Class-War-in-Titanic"><span class="toc-item-num">Task 3.&nbsp;&nbsp;</span>Class War in Titanic</a></div></p>

# %%
DATA_FOLDER = 'Data/ebola' # Use the data folder provided in Tutorial 02 - Intro to Pandas.

# %% [markdown]
# ## Task 1. Compiling Ebola Data
#
# The `DATA_FOLDER/ebola` folder contains summarized reports of Ebola cases from three countries (Guinea, Liberia and Sierra Leone) during the recent outbreak of the disease in West Africa. For each country, there are daily reports that contain various information about the outbreak in several cities in each country.
#
# Use pandas to import these data files into a single `Dataframe`.
# Using this `DataFrame`, calculate for *each country*, the *daily average per month* of *new cases* and *deaths*.
# Make sure you handle all the different expressions for *new cases* and *deaths* that are used in the reports.

# %%
import glob
import pandas as pd
import numpy as np
from datetime import datetime
pd.options.mode.chained_assignment = None  # default='warn', Mutes warnings when copying a slice from a DataFrame.

# %% [markdown]
# 1ST - IMPORT DATA FILES INTO A SINGLE DATAFRAME

# %%
#IMPORT GUINEA DATA
path = 'Data/ebola/guinea_data'
allFiles = glob.glob(path +  "/*.csv")
guinea = pd.DataFrame()
guinea_list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_)
    guinea_list_.append(df)
guinea = pd.concat(guinea_list_)

#IMPORT LIBERIA DATA
path = 'Data/ebola/liberia_data'
allFiles = glob.glob(path +  "/*.csv")
liberia = pd.DataFrame()
liberia_list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_)
    liberia_list_.append(df)
liberia = pd.concat(liberia_list_)

#IMPORT SIERRA LEONE DATA
path = 'Data/ebola/sl_data'
allFiles = glob.glob(path +  "/*.csv")
sl = pd.DataFrame()
sl_list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_)
    sl_list_.append(df)
sl = pd.concat(sl_list_)

# %%
guinea
# Out:
#    Beyla Boffa Conakry Coyah Dabola Dalaba        Date  \
# 0    NaN     0       5   NaN      0    NaN  2014-08-04
# 1    NaN     0       0   NaN      0    NaN  2014-08-04
# 2    NaN     0       1   NaN      0    NaN  2014-08-04
# 3    NaN     0       6   NaN      0    NaN  2014-08-04
# 4    NaN     0       9   NaN      0    NaN  2014-08-04
# 5    NaN     5       8   NaN      3    NaN  2014-08-04
# 6    NaN    18      78   NaN      1    NaN  2014-08-04
# 7    NaN    23      95   NaN      4    NaN  2014-08-04
# 8    NaN     0       0   NaN      0    NaN  2014-08-04
# 9    NaN     0       0   NaN      0    NaN  2014-08-04
# 10   NaN     0       0   NaN      0    NaN  2014-08-04
# 11   NaN     0       0   NaN      0    NaN  2014-08-04
# 12   NaN     0       2   NaN      0    NaN  2014-08-04
# 13   NaN     5       8   NaN      3    NaN  2014-08-04
# 14   NaN    11      32   NaN      1    NaN  2014-08-04
# 15   NaN    16      42   NaN      4    NaN  2014-08-04
# 16   NaN     0      21   NaN      0    NaN  2014-08-04
# 17   NaN     0      10   NaN      0    NaN  2014-08-04
# 18   NaN     0       0   NaN      0    NaN  2014-08-04
# 19   NaN     0      11   NaN      0    NaN  2014-08-04
# 20   NaN     6      20   NaN      0    NaN  2014-08-04
# 21   NaN     7      34   NaN      0    NaN  2014-08-04
# 22   NaN    10      48   NaN      1    NaN  2014-08-04
# 23   NaN     8      30   NaN      0    NaN  2014-08-04
# 24   NaN     3       4   NaN      1    NaN  2014-08-04
# 25   NaN     2       4   NaN      2    NaN  2014-08-04
# 26   NaN     0       5   NaN      0    NaN  2014-08-04
# 27   NaN     0       4   NaN      0    NaN  2014-08-04
# 28   NaN    13      57   NaN      2    NaN  2014-08-04
# 29   NaN    10      38   NaN      2    NaN  2014-08-04
# ..   ...   ...     ...   ...    ...    ...         ...
# 2    NaN   NaN       2   NaN    NaN    NaN  2014-10-01
# 3      0     0      17     0      0      0  2014-10-01
# 4      0     0      19     0      0      0  2014-10-01
# 5      0     5      10     0      3      0  2014-10-01
# 6      2    19     170    12      1      6  2014-10-01
# 7      2    24     199    12      4      6  2014-10-01
# 8      0    20     355     6      3      1  2014-10-01
# 9    NaN   NaN     NaN   NaN    NaN    NaN  2014-10-01
# 10     0     0       0     0      0      0  2014-10-01
# 11     0     5      10     0      3      0  2014-10-01
# 12     1    11      68     5      1      0  2014-10-01
# 13     0    16      78     5      4      0  2014-10-01
# 14  100%   67%     39%   42%   100%     0%  2014-10-01
# 15   NaN   NaN       2   NaN    NaN    NaN  2014-10-01
# 16     0     0      40     1      0      0  2014-10-01
# 17     0     0       0     0      0      0  2014-10-01
# 18     0     0      18     0      0      0  2014-10-01
# 19   NaN   NaN      15   NaN    NaN    NaN  2014-10-01
# 20     0     0      48     0      0      0  2014-10-01
# 21     0     0       9     0      0      0  2014-10-01
# 22     0     0     571     0      0      0  2014-10-01
# 23   NaN   NaN     NaN   NaN    NaN    NaN  2014-10-01
# 24     2   397    3319   116     69     34  2014-10-01
# 25   929     0     825    98      0     34  2014-10-01
# 26    29     0     778    98      0     20  2014-10-01
# 27     0   397    2494    17     69      0  2014-10-01
# 28     0     0       0     1      0      0  2014-10-01
# 29   NaN   NaN      16   NaN    NaN    NaN  2014-10-01
# 30   NaN   NaN       0   NaN    NaN    NaN  2014-10-01
# 31   NaN   NaN    1171   NaN    NaN    NaN  2014-10-01
#
#                                         Description Dinguiraye Dubreka  ...   \
# 0                             New cases of suspects          0       0  ...
# 1                            New cases of probables          0       0  ...
# 2                            New cases of confirmed          0       0  ...
# 3                 Total new cases registered so far          0       0  ...
# 4                           Total cases of suspects          0       0  ...
# 5                          Total cases of probables          1       0  ...
# 6                          Total cases of confirmed          0       0  ...
# 7      Cumulative (confirmed + probable + suspects)          1       0  ...
# 8                       New deaths registered today          0       0  ...
# 9           New deaths registered today (confirmed)          0       0  ...
# 10          New deaths registered today (probables)          0       0  ...
# 11           New deaths registered today (suspects)          0       0  ...
# 12                         Total deaths of suspects          0       0  ...
# 13                        Total deaths of probables          1       0  ...
# 14                        Total deaths of confirmed          0       0  ...
# 15  Total deaths (confirmed + probables + suspects)          1       0  ...
# 16                           Total PEC center today          0       0  ...
# 17               Total PEC center today (confirmed)          0       0  ...
# 18               Total PEC center today (probables)          0       0  ...
# 19                Total PEC center today (suspects)          0       0  ...
# 20        Total of deaths in confirmed cases in CTE          0       0  ...
# 21         Total of cured in confirmed cases in CTE          0       0  ...
# 22                   Number of male confirmed cases          0       0  ...
# 23                 Number of female confirmed cases          0       0  ...
# 24                   Number of male probables cases          0       0  ...
# 25                 Number of female probables cases          1       0  ...
# 26                    Number of male suspects cases          0       0  ...
# 27                  Number of female suspects cases          0       0  ...
# 28                       Total number of male cases          0       0  ...
# 29                     Total number of female cases          1       0  ...
# ..                                              ...        ...     ...  ...
# 2                            New cases of confirmed        NaN     NaN  ...
# 3                 Total new cases registered so far          0       0  ...
# 4                           Total cases of suspects          0       0  ...
# 5                          Total cases of probables          1       0  ...
# 6                          Total cases of confirmed          0      21  ...
# 7      Cumulative (confirmed + probable + suspects)          1      21  ...
# 8                   Total suspected non-class cases          0      20  ...
# 9                             New deaths registered        NaN     NaN  ...
# 10                         Total deaths of suspects          0       0  ...
# 11                        Total deaths of probables          1       0  ...
# 12                        Total deaths of confirmed          0       7  ...
# 13  Total deaths (confirmed + probables + suspects)          1       7  ...
# 14        Fatality rate for confirmed and probables       100%     33%  ...
# 15      New cases of confirmed among health workers        NaN     NaN  ...
# 16     Total case of confirmed among health workers          0       3  ...
# 17       New deaths registered among health workers          0       0  ...
# 18     Total deaths registered among health workers          0       1  ...
# 19                         New admits to CTE so far        NaN     NaN  ...
# 20        Total number of hospitalized cases in CTE          0       0  ...
# 21                   Total number of exits from CTE          0       0  ...
# 22                Total number of admissions to CTE          0       0  ...
# 23                   New contacts registered so far        NaN     NaN  ...
# 24        Total contacts registered from start date          0     341  ...
# 25               Number of contacts to follow today          0      49  ...
# 26                Number of contacts followed today          0      49  ...
# 27      Number of contacts out of the track 21 days          0     292  ...
# 28             Number of contacts lost to follow up          0       0  ...
# 29                Number of samples collected today        NaN     NaN  ...
# 30                     Number of samples under test        NaN     NaN  ...
# 31                             Total samples tested        NaN     NaN  ...
#
#    Kouroussa  Lola Macenta Mzerekore Nzerekore Pita Siguiri Telimele Totals  \
# 0          0   NaN       0       NaN         0    0       0        0      5
# 1          0   NaN       0       NaN         0    0       0        0      0
# 2          0   NaN       0       NaN         0    0       0        0      4
# 3          0   NaN       0       NaN         0    0       0        0      9
# 4          0   NaN       0       NaN         0    0       0        0     11
# 5          2   NaN      11       NaN         0    1       0        3    133
# 6          2   NaN      28       NaN         4    1       6       23    351
# 7          4   NaN      39       NaN         4    2       6       26    495
# 8          0   NaN       0       NaN         0    0       0        0      2
# 9          0   NaN       0       NaN         0    0       0        0      2
# 10         0   NaN       0       NaN         0    0       0        0      0
# 11         0   NaN       0       NaN         0    0       0        0      0
# 12         0   NaN       0       NaN         0    0       0        0      2
# 13         2   NaN      11       NaN         0    1       0        3    133
# 14         1   NaN      18       NaN         1    1       3        7    228
# 15         3   NaN      29       NaN         1    2       3       10    363
# 16         0   NaN       0       NaN         0    0       2        0     31
# 17         0   NaN       0       NaN         0    0       2        0     18
# 18         0   NaN       0       NaN         0    0       0        0      0
# 19         0   NaN       0       NaN         0    0       0        0     13
# 20         0   NaN      10       NaN         0    0       2        5    138
# 21         0   NaN       8       NaN         0    0       0        9     89
# 22         1   NaN      14       NaN         2    0       6        6    161
# 23         1   NaN      14       NaN         2    1       0       17    190
# 24         2   NaN       5       NaN         0    1       0        1     52
# 25         0   NaN       6       NaN         0    0       0        2     81
# 26         0   NaN       0       NaN         0    0       2        0      7
# 27         0   NaN       0       NaN         0    0       0        0      6
# 28         3   NaN      19       NaN         2    1       8        7    220
# 29         1   NaN      20       NaN         2    1       0       19    277
# ..       ...   ...     ...       ...       ...  ...     ...      ...    ...
# 2        NaN   NaN       2       NaN       NaN  NaN     NaN      NaN      6
# 3          0     9       5       NaN         1    0       0        0     34
# 4          0     9       9       NaN         2    1       0        0     45
# 5          2     0      16       NaN        17    1       0        3    177
# 6          2     2     378       NaN        31    6       6       23    977
# 7          4    11     403       NaN        50    8       6       26   1199
# 8          2     4     197       NaN        16   18       9       18    974
# 9        NaN   NaN      15       NaN       NaN  NaN     NaN      NaN     15
# 10         0     0       0       NaN         0    0       0        0      0
# 11         2     0      16       NaN        17    1       0        3    177
# 12         2     2     230       NaN        15    2       3        7    562
# 13         4     0     246       NaN        32    3       3       10    739
# 14      100%  100%     61%       NaN       64%  38%     50%      38%    62%
# 15       NaN   NaN     NaN       NaN       NaN  NaN     NaN      NaN      2
# 16         0     0       9       NaN         2    0       2        2     69
# 17         0     0       0       NaN         0    0       0        0      0
# 18         0     0       7       NaN         1    0       0        1     35
# 19       NaN   NaN     NaN       NaN       NaN  NaN     NaN      NaN     25
# 20         0   NaN      12       NaN         0    0       0        0    114
# 21         0   NaN      15       NaN         0    0       0        0     29
# 22         0   NaN      27       NaN         0    0      13       41   1576
# 23       NaN   NaN     NaN       NaN       NaN  NaN     NaN      NaN      0
# 24        94     0    1563       NaN       353  140     141      259  11772
# 25         0     0    1038       NaN       126    0       0        0   2661
# 26         0     0    1038       NaN       126    0       0        0   2595
# 27        94     0     525       NaN       227  140     141      259   9110
# 28         0     0       0       NaN         0    0       0        0      1
# 29       NaN   NaN       0       NaN       NaN  NaN     NaN      NaN     25
# 30       NaN   NaN       0       NaN       NaN  NaN     NaN      NaN      0
# 31       NaN   NaN       0       NaN       NaN  NaN     NaN      NaN   2832
#
#    Yomou
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# ..   ...
# 2    NaN
# 3      0
# 4      0
# 5      0
# 6     11
# 7     11
# 8      4
# 9    NaN
# 10     0
# 11     0
# 12     5
# 13     5
# 14   45%
# 15   NaN
# 16     1
# 17     0
# 18     1
# 19   NaN
# 20     0
# 21     0
# 22     0
# 23   NaN
# 24    56
# 25     0
# 26     0
# 27    56
# 28     0
# 29   NaN
# 30   NaN
# 31   NaN
#
# [714 rows x 25 columns]

# %%
guinea.Description.unique()
# Out:
# array(['New cases of suspects', 'New cases of probables',
#        'New cases of confirmed', 'Total new cases registered so far',
#        'Total cases of suspects', 'Total cases of probables',
#        'Total cases of confirmed',
#        'Cumulative (confirmed + probable + suspects)',
#        'New deaths registered today',
#        'New deaths registered today (confirmed)',
#        'New deaths registered today (probables)',
#        'New deaths registered today (suspects)',
#        'Total deaths of suspects', 'Total deaths of probables',
#        'Total deaths of confirmed',
#        'Total deaths (confirmed + probables + suspects)',
#        'Total PEC center today', 'Total PEC center today (confirmed)',
#        'Total PEC center today (probables)',
#        'Total PEC center today (suspects)',
#        'Total of deaths in confirmed cases in CTE',
#        'Total of cured in confirmed cases in CTE',
#        'Number of male confirmed cases',
#        'Number of female confirmed cases',
#        'Number of male probables cases',
#        'Number of female probables cases', 'Number of male suspects cases',
#        'Number of female suspects cases', 'Total number of male cases',
#        'Total number of female cases',
#        'Number of confirmed cases among health workers',
#        'Number of deaths of confirmed cases among health workers',
#        'Number of probables cases among health workers',
#        'Number of deaths of probables cases among health workers',
#        'Number of suspects cases among health workers',
#        'Number of death of confirmed cases among health workers',
#        'Total contacts registered from start date',
#        'Number of contacts to follow today',
#        'Number of contacts out of track',
#        'Number of contacts followed yesterday',
#        'Number of patients tested', 'Number of samples collected',
#        'Total suspected non-class cases', 'New deaths registered',
#        'Fatality rate for confirmed and probables',
#        'New cases of confirmed among health workers',
#        'Total case of confirmed among health workers',
#        'New deaths registered among health workers',
#        'Total deaths registered among health workers',
#        'New admits to CTE so far',
#        'Total number of hospitalized cases in CTE',
#        'Total number of exits from CTE',
#        'Total number of admissions to CTE',
#        'New contacts registered so far',
#        'Number of contacts followed today',
#        'Number of contacts out of the track 21 days',
#        'Number of contacts lost to follow up',
#        'Number of samples collected today', 'Number of samples under test',
#        'Total samples tested'], dtype=object)

# %%
liberia
# Out:
#     Bomi County  Bong County       Date  Gbarpolu County  Grand Bassa  \
# 0           NaN          NaN  6/16/2014              NaN          NaN
# 1           NaN          NaN  6/16/2014              NaN          NaN
# 2           NaN          NaN  6/16/2014              NaN          NaN
# 3           NaN          NaN  6/16/2014              NaN          NaN
# 4           NaN          NaN  6/16/2014              NaN          NaN
# 5           NaN          NaN  6/16/2014              NaN          NaN
# 6           NaN          NaN  6/16/2014              NaN          NaN
# 7           NaN          NaN  6/16/2014              NaN          NaN
# 8           NaN          NaN  6/16/2014              NaN          NaN
# 9           NaN          NaN  6/16/2014              NaN          NaN
# 10          NaN          NaN  6/16/2014              NaN          NaN
# 11          NaN          NaN  6/16/2014              NaN          NaN
# 12          NaN          NaN  6/16/2014              NaN          NaN
# 13          NaN          NaN  6/16/2014              NaN          NaN
# 14          NaN          NaN  6/16/2014              NaN          NaN
# 15          NaN          NaN  6/16/2014              NaN          NaN
# 16          NaN          NaN  6/16/2014              NaN          NaN
# 17          NaN          NaN  6/16/2014              NaN          NaN
# 18          NaN          NaN  6/16/2014              NaN          NaN
# 19          NaN          NaN  6/16/2014              NaN          NaN
# 20          NaN          NaN  6/16/2014              NaN          NaN
# 21          NaN          NaN  6/16/2014              NaN          NaN
# 22          NaN          NaN  6/16/2014              NaN          NaN
# 23          NaN          NaN  6/16/2014              NaN          NaN
# 24          NaN          NaN  6/16/2014              NaN          NaN
# 25          NaN          NaN  6/16/2014              NaN          NaN
# 26          NaN          NaN  6/16/2014              NaN          NaN
# 27          NaN          NaN  6/16/2014              NaN          NaN
# 28          NaN          NaN  6/16/2014              NaN          NaN
# 29          NaN          NaN  6/16/2014              NaN          NaN
# ..          ...          ...        ...              ...          ...
# 2           NaN          NaN  12/9/2014              NaN          NaN
# 3           NaN          NaN  12/9/2014              NaN          NaN
# 4           NaN          NaN  12/9/2014              NaN          NaN
# 5           NaN          NaN  12/9/2014              NaN          NaN
# 6           NaN          NaN  12/9/2014              NaN          NaN
# 7         158.0        125.0  12/9/2014             10.0         70.0
# 8           NaN          NaN  12/9/2014              NaN          NaN
# 9           NaN          NaN  12/9/2014              NaN          NaN
# 10          NaN          NaN  12/9/2014              NaN          NaN
# 11          NaN          NaN  12/9/2014              NaN          NaN
# 12          NaN          NaN  12/9/2014              NaN          NaN
# 13          NaN          NaN  12/9/2014              NaN          NaN
# 14          NaN          NaN  12/9/2014              NaN          NaN
# 15          NaN          NaN  12/9/2014              NaN          NaN
# 16          NaN          NaN  12/9/2014              NaN          NaN
# 17          NaN          NaN  12/9/2014              NaN          NaN
# 18          NaN          NaN  12/9/2014              NaN          NaN
# 19          NaN          NaN  12/9/2014              NaN          NaN
# 20          NaN          NaN  12/9/2014              NaN          NaN
# 21          NaN          NaN  12/9/2014              NaN          NaN
# 22          NaN          NaN  12/9/2014              NaN          NaN
# 23         82.0        390.0  12/9/2014             26.0         45.0
# 24         74.0         32.0  12/9/2014              3.0         70.0
# 25        137.0        135.0  12/9/2014             10.0         43.0
# 26          NaN          NaN  12/9/2014              NaN          NaN
# 27          NaN          NaN  12/9/2014              NaN          NaN
# 28          NaN          NaN  12/9/2014              NaN          NaN
# 29          NaN          NaN  12/9/2014              NaN          NaN
# 30          NaN          NaN  12/9/2014              NaN          NaN
# 31        293.0        557.0  12/9/2014             39.0        158.0
#
#     Grand Cape Mount  Grand Gedeh  Grand Kru  Lofa County  Margibi County  \
# 0                NaN          NaN        NaN          1.0             NaN
# 1                NaN          NaN        NaN          0.0             NaN
# 2                NaN          NaN        NaN         21.0             NaN
# 3                NaN          NaN        NaN          1.0             NaN
# 4                NaN          NaN        NaN          4.0             NaN
# 5                NaN          NaN        NaN          2.0             NaN
# 6                NaN          NaN        NaN          2.0             NaN
# 7                NaN          NaN        NaN          8.0             NaN
# 8                NaN          NaN        NaN          NaN             NaN
# 9                NaN          NaN        NaN         41.0             NaN
# 10               NaN          NaN        NaN         95.0             NaN
# 11               NaN          NaN        NaN         95.0             NaN
# 12               NaN          NaN        NaN         95.0             NaN
# 13               NaN          NaN        NaN         11.0             NaN
# 14               NaN          NaN        NaN          0.0             NaN
# 15               NaN          NaN        NaN          1.0             NaN
# 16               NaN          NaN        NaN          5.0             NaN
# 17               NaN          NaN        NaN          3.0             NaN
# 18               NaN          NaN        NaN          5.0             NaN
# 19               NaN          NaN        NaN          NaN             NaN
# 20               NaN          NaN        NaN          0.0             NaN
# 21               NaN          NaN        NaN          0.0             NaN
# 22               NaN          NaN        NaN          0.0             NaN
# 23               NaN          NaN        NaN          2.0             NaN
# 24               NaN          NaN        NaN          0.0             NaN
# 25               NaN          NaN        NaN          1.0             NaN
# 26               NaN          NaN        NaN          4.0             NaN
# 27               NaN          NaN        NaN          2.0             NaN
# 28               NaN          NaN        NaN          8.0             NaN
# 29               NaN          NaN        NaN          1.0             NaN
# ..               ...          ...        ...          ...             ...
# 2                NaN          NaN        NaN          NaN             NaN
# 3                NaN          NaN        NaN          NaN             NaN
# 4                NaN          NaN        NaN          NaN             NaN
# 5                NaN          NaN        NaN          NaN             NaN
# 6                NaN          NaN        NaN          NaN             NaN
# 7               87.0          5.0       27.0        384.0           557.0
# 8                NaN          NaN        NaN          NaN             NaN
# 9                NaN          NaN        NaN          NaN             NaN
# 10               NaN          NaN        NaN          NaN             NaN
# 11               NaN          NaN        NaN          NaN             NaN
# 12               NaN          NaN        NaN          NaN             NaN
# 13               NaN          NaN        NaN          NaN             NaN
# 14               NaN          NaN        NaN          NaN             NaN
# 15               NaN          NaN        NaN          NaN             NaN
# 16               NaN          NaN        NaN          NaN             NaN
# 17               NaN          NaN        NaN          NaN             NaN
# 18               NaN          NaN        NaN          NaN             NaN
# 19               NaN          NaN        NaN          NaN             NaN
# 20               NaN          NaN        NaN          NaN             NaN
# 21               NaN          NaN        NaN          NaN             NaN
# 22               NaN          NaN        NaN          NaN             NaN
# 23              47.0          8.0       14.0        171.0           409.0
# 24              50.0          0.0       18.0        148.0           163.0
# 25              68.0          2.0        4.0        326.0           383.0
# 26               NaN          NaN        NaN          NaN             NaN
# 27               NaN          NaN        NaN          NaN             NaN
# 28               NaN          NaN        NaN          NaN             NaN
# 29               NaN          NaN        NaN          NaN             NaN
# 30               NaN          NaN        NaN          NaN             NaN
# 31             165.0         10.0       36.0        645.0          1255.0
#
#     Maryland County  Montserrado County  National  Nimba County  \
# 0               NaN                 0.0       1.0           NaN
# 1               NaN                 0.0       0.0           NaN
# 2               NaN                 7.0      28.0           NaN
# 3               NaN                 0.0       2.0           NaN
# 4               NaN                 0.0       8.0           NaN
# 5               NaN                 0.0       6.0           NaN
# 6               NaN                 0.0       2.0           NaN
# 7               NaN                 0.0      16.0           NaN
# 8               NaN                 NaN       NaN           NaN
# 9               NaN                 0.0      41.0           NaN
# 10              NaN                13.0     108.0           NaN
# 11              NaN                 0.0      95.0           NaN
# 12              NaN                 0.0      95.0           NaN
# 13              NaN                 0.0      11.0           NaN
# 14              NaN                 0.0       NaN           NaN
# 15              NaN                 0.0       1.0           NaN
# 16              NaN                 0.0       5.0           NaN
# 17              NaN                 0.0       3.0           NaN
# 18              NaN                 0.0       5.0           NaN
# 19              NaN                 NaN       0.0           NaN
# 20              NaN                 1.0       1.0           NaN
# 21              NaN                 0.0       0.0           NaN
# 22              NaN                 1.0       1.0           NaN
# 23              NaN                 0.0       2.0           NaN
# 24              NaN                 1.0       1.0           NaN
# 25              NaN                 0.0       1.0           NaN
# 26              NaN                 0.0       4.0           NaN
# 27              NaN                 4.0       6.0           NaN
# 28              NaN                 4.0      12.0           NaN
# 29              NaN                 0.0       1.0           NaN
# ..              ...                 ...       ...           ...
# 2               NaN                 NaN       NaN           NaN
# 3               NaN                 NaN       NaN           NaN
# 4               NaN                 NaN       NaN           NaN
# 5               NaN                 NaN       NaN           NaN
# 6               NaN                 NaN       NaN           NaN
# 7              19.0              1747.0    3290.0          53.0
# 8               NaN                 NaN       NaN           NaN
# 9               NaN                 NaN       NaN           NaN
# 10              NaN                 NaN       NaN           NaN
# 11              NaN                 NaN       NaN           NaN
# 12              NaN                 NaN       NaN           NaN
# 13              NaN                 NaN       NaN           NaN
# 14              NaN                 NaN       NaN           NaN
# 15              NaN                 NaN       NaN           NaN
# 16              NaN                 NaN       NaN           NaN
# 17              NaN                 NaN       NaN           NaN
# 18              NaN                 NaN       NaN           NaN
# 19              NaN                 NaN       NaN           NaN
# 20              NaN                 NaN       NaN           NaN
# 21              NaN                 NaN       NaN           NaN
# 22              NaN                 NaN       NaN           NaN
# 23             17.0              1726.0    3050.0          78.0
# 24              2.0               194.0    1801.0         128.0
# 25              4.0              1676.0    2946.0         114.0
# 26              NaN                 NaN       NaN           NaN
# 27              NaN                 NaN       NaN           NaN
# 28              NaN                 NaN       NaN           NaN
# 29              NaN                 NaN       NaN           NaN
# 30              NaN                 NaN       NaN           NaN
# 31             23.0              4196.0    7797.0         320.0
#
#     River Gee County  RiverCess County  Sinoe County  Unnamed: 18  \
# 0                NaN               NaN           NaN          NaN
# 1                NaN               NaN           NaN          NaN
# 2                NaN               NaN           NaN          NaN
# 3                NaN               NaN           NaN          NaN
# 4                NaN               NaN           NaN          NaN
# 5                NaN               NaN           NaN          NaN
# 6                NaN               NaN           NaN          NaN
# 7                NaN               NaN           NaN          NaN
# 8                NaN               NaN           NaN          NaN
# 9                NaN               NaN           NaN          NaN
# 10               NaN               NaN           NaN          NaN
# 11               NaN               NaN           NaN          NaN
# 12               NaN               NaN           NaN          NaN
# 13               NaN               NaN           NaN          NaN
# 14               NaN               NaN           NaN          NaN
# 15               NaN               NaN           NaN          NaN
# 16               NaN               NaN           NaN          NaN
# 17               NaN               NaN           NaN          NaN
# 18               NaN               NaN           NaN          NaN
# 19               NaN               NaN           NaN          NaN
# 20               NaN               NaN           NaN          NaN
# 21               NaN               NaN           NaN          NaN
# 22               NaN               NaN           NaN          NaN
# 23               NaN               NaN           NaN          NaN
# 24               NaN               NaN           NaN          NaN
# 25               NaN               NaN           NaN          NaN
# 26               NaN               NaN           NaN          NaN
# 27               NaN               NaN           NaN          NaN
# 28               NaN               NaN           NaN          NaN
# 29               NaN               NaN           NaN          NaN
# ..               ...               ...           ...          ...
# 2                NaN               NaN           NaN          NaN
# 3                NaN               NaN           NaN          NaN
# 4                NaN               NaN           NaN          NaN
# 5                NaN               NaN           NaN          NaN
# 6                NaN               NaN           NaN          NaN
# 7                8.0              26.0          14.0          NaN
# 8                NaN               NaN           NaN          NaN
# 9                NaN               NaN           NaN          NaN
# 10               NaN               NaN           NaN          NaN
# 11               NaN               NaN           NaN          NaN
# 12               NaN               NaN           NaN          NaN
# 13               NaN               NaN           NaN          NaN
# 14               NaN               NaN           NaN          NaN
# 15               NaN               NaN           NaN          NaN
# 16               NaN               NaN           NaN          NaN
# 17               NaN               NaN           NaN          NaN
# 18               NaN               NaN           NaN          NaN
# 19               NaN               NaN           NaN          NaN
# 20               NaN               NaN           NaN          NaN
# 21               NaN               NaN           NaN          NaN
# 22               NaN               NaN           NaN          NaN
# 23               7.0               9.0          21.0          NaN
# 24               4.0              12.0           3.0          NaN
# 25               7.0              20.0          16.0          NaN
# 26               NaN               NaN           NaN          NaN
# 27               NaN               NaN           NaN          NaN
# 28               NaN               NaN           NaN          NaN
# 29               NaN               NaN           NaN          NaN
# 30               NaN               NaN           NaN          NaN
# 31              19.0              41.0          40.0          NaN
#
#                                              Variable
# 0                                 Specimens collected
# 1                       Specimens pending for testing
# 2                              Total specimens tested
# 3                               Newly reported deaths
# 4                    Total death/s in confirmed cases
# 5                     Total death/s in probable cases
# 6                    Total death/s in suspected cases
# 7   Total death/s in confirmed, probable, suspecte...
# 8   Case Fatality Rate (CFR) - Confirmed & Probabl...
# 9                             Newly reported contacts
# 10                              Total contacts listed
# 11                          Currently under follow-up
# 12                                      Contacts seen
# 13            Contacts who completed 21 day follow-up
# 14                         Contacts lost to follow-up
# 15                                     New admissions
# 16             Total no. currently in Treatment Units
# 17                                   Total discharges
# 18                     Cumulative admission/isolation
# 19                        Newly Reported Cases in HCW
# 20                         Cumulative cases among HCW
# 21                       Newly Reported deaths in HCW
# 22                        Cumulative deaths among HCW
# 23                             New Case/s (Suspected)
# 24                              New Case/s (Probable)
# 25                             New case/s (confirmed)
# 26                              Total suspected cases
# 27                               Total probable cases
# 28                              Total confirmed cases
# 29  Total Number of Confirmed Cases of Sierra Leon...
# ..                                                ...
# 2                              Total specimens tested
# 3                               Newly reported deaths
# 4                    Total death/s in confirmed cases
# 5                     Total death/s in probable cases
# 6                    Total death/s in suspected cases
# 7   Total death/s in confirmed, \n probable, suspe...
# 8   Case Fatality Rate (CFR) - \n Confirmed & Prob...
# 9                             Newly reported contacts
# 10                              Total contacts listed
# 11                          Currently under follow-up
# 12                                      Contacts seen
# 13         Contacts who completed 21 day \n follow-up
# 14                         Contacts lost to follow-up
# 15                                     New admissions
# 16          Total no. currently in Treatment \n Units
# 17                                   Total discharges
# 18                     Cumulative admission/isolation
# 19                        Newly Reported Cases in HCW
# 20                         Cumulative cases among HCW
# 21                       Newly Reported deaths in HCW
# 22                        Cumulative deaths among HCW
# 23                             New Case/s (Suspected)
# 24                              New Case/s (Probable)
# 25                             New case/s (confirmed)
# 26                              Total suspected cases
# 27                               Total probable cases
# 28                              Total confirmed cases
# 29  Total Number of Confirmed Cases \n of Sierra L...
# 30  Total Number of Confirmed Cases \n of Guinean ...
# 31  Cumulative confirmed, probable and suspected c...
#
# [3152 rows x 19 columns]

# %%
liberia.Variable.unique()
# Out:
# array(['Specimens collected', 'Specimens pending for testing',
#        'Total specimens tested', 'Newly reported deaths',
#        'Total death/s in confirmed cases',
#        'Total death/s in probable cases',
#        'Total death/s in suspected cases',
#        'Total death/s in confirmed, probable, suspected cases',
#        'Case Fatality Rate (CFR) - Confirmed & Probable Cases',
#        'Newly reported contacts', 'Total contacts listed',
#        'Currently under follow-up', 'Contacts seen',
#        'Contacts who completed 21 day follow-up',
#        'Contacts lost to follow-up', 'New admissions',
#        'Total no. currently in Treatment Units', 'Total discharges',
#        'Cumulative admission/isolation', 'Newly Reported Cases in HCW',
#        'Cumulative cases among HCW', 'Newly Reported deaths in HCW',
#        'Cumulative deaths among HCW', 'New Case/s (Suspected)',
#        'New Case/s (Probable)', 'New case/s (confirmed)',
#        'Total suspected cases', 'Total probable cases',
#        'Total confirmed cases',
#        'Total Number of Confirmed Cases of Sierra Leonean Nationality',
#        'Total Number of Confirmed Cases of Guinean Nationality',
#        'Cumulative (confirmed + probable + suspected)',
#        'Total Case/s (Suspected)', 'Total Case/s (Probable)',
#        'Total case/s (confirmed)', 'Cumulative CFR',
#        'Cumulative (confirmed + probable + suspects)',
#        'Total death/s in confirmed,  probable, suspected cases',
#        'Cumulative confirmed, probable and suspected cases',
#        'Total death/s in confirmed, \n probable, suspected cases',
#        'Case Fatality Rate (CFR) - \n Confirmed & Probable Cases',
#        'Contacts who completed 21 day \n follow-up',
#        'Total no. currently in Treatment \n Units',
#        'Total Number of Confirmed Cases \n of Sierra Leonean Nationality',
#        'Total Number of Confirmed Cases \n of Guinean Nationality'], dtype=object)

# %%
sl
# Out:
#     34 Military Hospital       Bo  Bo EMC  Bombali   Bonthe  Hastings-F/Town  \
# 0                    NaN   654142     NaN   494139   168729              NaN
# 1                    NaN        0     NaN        0        0              NaN
# 2                    NaN        1     NaN        0        0              NaN
# 3                    NaN        1     NaN        0        0              NaN
# 4                    NaN        0     NaN        0        0              NaN
# 5                    NaN       54     NaN       10        0              NaN
# 6                    NaN        2     NaN        1        0              NaN
# 7                    NaN        1     NaN        1        0              NaN
# 8                    NaN       22     NaN        7        1              NaN
# 9                    NaN        0     NaN        0        0              NaN
# 10                   NaN        0     NaN        0        0              NaN
# 11                   NaN        2     NaN        1        0              NaN
# 12                   NaN      9.1     NaN     14.3        0              NaN
# 13                   NaN      NaN     NaN      NaN      NaN              NaN
# 14                   NaN      NaN     NaN      NaN      NaN              NaN
# 15                   NaN      NaN     NaN      NaN      NaN              NaN
# 16                   NaN      NaN     NaN      NaN      NaN              NaN
# 17                   NaN      NaN     NaN      NaN      NaN              NaN
# 18                   NaN      NaN     NaN      NaN      NaN              NaN
# 19                   NaN      NaN     NaN      NaN      NaN              NaN
# 20                   NaN      227     NaN      161       26              NaN
# 21                   NaN       67     NaN       16       26              NaN
# 22                   NaN      160     NaN      161        0              NaN
# 23                   NaN        6     NaN        5        0              NaN
# 24                   NaN      157     NaN      141        0              NaN
# 25                   NaN        0     NaN        0        0              NaN
# 26                   NaN        3     NaN       20        0              NaN
# 27                   NaN        0     NaN       16        0              NaN
# 28                   NaN      98%     NaN      97%      NaN              NaN
# 0                    NaN  654,142     NaN  494,139  168,729              NaN
# ..                   ...      ...     ...      ...      ...              ...
# 7                    NaN        1     NaN        6        0              NaN
# 8                    NaN      297     NaN      907        4              NaN
# 9                    NaN      NaN     NaN      NaN      NaN              NaN
# 10                   NaN      NaN     NaN      NaN      NaN              NaN
# 11                   NaN      NaN     NaN      NaN      NaN              NaN
# 12                   NaN      NaN     NaN      NaN      NaN              NaN
# 13                   NaN      NaN     NaN      NaN      NaN              NaN
# 14                   NaN      NaN     NaN      NaN      NaN              NaN
# 15                   NaN      NaN     NaN      NaN      NaN              NaN
# 16                   NaN      NaN     NaN      NaN      NaN              NaN
# 17                   NaN      NaN     NaN      NaN      NaN              NaN
# 18                   NaN      NaN     NaN      NaN      NaN              NaN
# 19                   NaN      NaN     NaN      NaN      NaN              NaN
# 20                   NaN      NaN     NaN      NaN      NaN              NaN
# 21                   NaN      NaN     NaN      NaN      NaN              NaN
# 22                   NaN      NaN     NaN      NaN      NaN              NaN
# 23                   NaN      NaN     NaN      NaN      NaN              NaN
# 24                   NaN      NaN     NaN      NaN      NaN              NaN
# 25                   NaN      NaN     NaN      NaN      NaN              NaN
# 26                   NaN      NaN     NaN      NaN      NaN              NaN
# 27                   NaN      NaN     NaN      NaN      NaN              NaN
# 28                   NaN      NaN     NaN      NaN      NaN              NaN
# 29                   NaN      NaN     NaN      NaN      NaN              NaN
# 30                   NaN      NaN     NaN      NaN      NaN              NaN
# 31                   NaN      NaN     NaN      NaN      NaN              NaN
# 32                   NaN      NaN     NaN      NaN      NaN              NaN
# 33                   NaN      NaN     NaN      NaN      NaN              NaN
# 34                   NaN      NaN     NaN      NaN      NaN              NaN
# 35                   NaN      NaN     NaN      NaN      NaN              NaN
# 36                   NaN      NaN     NaN      NaN      NaN              NaN
#
#    Kailahun   Kambia   Kenema  Kenema (IFRC)           ...            \
# 0    465048   341690   653013            NaN           ...
# 1         0        0        3            NaN           ...
# 2         0        0        9            NaN           ...
# 3         0        0        0            NaN           ...
# 4         0        0        9            NaN           ...
# 5       201        1      269            NaN           ...
# 6         0        0       10            NaN           ...
# 7        32        0        0            NaN           ...
# 8       378        1      259            NaN           ...
# 9         2        0        1            NaN           ...
# 10       32        0        0            NaN           ...
# 11      151        0      104            NaN           ...
# 12     39.9        0     40.2            NaN           ...
# 13       16      NaN        7            NaN           ...
# 14       53      NaN       41            NaN           ...
# 15      341      NaN      303            NaN           ...
# 16        5      NaN        3            NaN           ...
# 17      104      NaN      154            NaN           ...
# 18        7      NaN        2            NaN           ...
# 19      134      NaN       59            NaN           ...
# 20      NaN        0    1,356            NaN           ...
# 21      NaN        0      701            NaN           ...
# 22      321        0      497            NaN           ...
# 23      321        0       73            NaN           ...
# 24      305        0      427            NaN           ...
# 25       11        0        3            NaN           ...
# 26       16        0       64            NaN           ...
# 27       12        0       38            NaN           ...
# 28      98%      NaN      61%            NaN           ...
# 0   465,048  341,690  653,013            NaN           ...
# ..      ...      ...      ...            ...           ...
# 7        32        0        0            NaN           ...
# 8       565       96      495            NaN           ...
# 9       NaN      NaN      NaN            NaN           ...
# 10      NaN      NaN      NaN            NaN           ...
# 11      NaN      NaN      NaN            NaN           ...
# 12      NaN      NaN      NaN            NaN           ...
# 13      NaN      NaN      NaN            NaN           ...
# 14      NaN      NaN      NaN            NaN           ...
# 15      NaN      NaN      NaN            NaN           ...
# 16      NaN      NaN      NaN            NaN           ...
# 17      NaN      NaN      NaN            NaN           ...
# 18      NaN      NaN      NaN            NaN           ...
# 19      NaN      NaN      NaN            NaN           ...
# 20      NaN      NaN      NaN            NaN           ...
# 21      NaN      NaN      NaN            NaN           ...
# 22      NaN      NaN      NaN            NaN           ...
# 23      NaN      NaN      NaN            NaN           ...
# 24      NaN      NaN      NaN            NaN           ...
# 25      NaN      NaN      NaN            NaN           ...
# 26      NaN      NaN      NaN            NaN           ...
# 27      NaN      NaN      NaN            NaN           ...
# 28      NaN      NaN      NaN            NaN           ...
# 29      NaN      NaN      NaN            NaN           ...
# 30      NaN      NaN      NaN            NaN           ...
# 31      NaN      NaN      NaN            NaN           ...
# 32      NaN      NaN      NaN            NaN           ...
# 33      NaN      NaN      NaN            NaN           ...
# 34      NaN      NaN      NaN            NaN           ...
# 35      NaN      NaN      NaN            NaN           ...
# 36      NaN      NaN      NaN            NaN           ...
#
#    Port Loko  Pujehun Tonkolili Unnamed: 18 Western area  \
# 0     557978   335574    434937         NaN          NaN
# 1          1        0         0         NaN          NaN
# 2          0        0         0         NaN          NaN
# 3          0        0         0         NaN          NaN
# 4          2        0         0         NaN          NaN
# 5          7        2        10         NaN          NaN
# 6          0        0         0         NaN          NaN
# 7          1        0         0         NaN          NaN
# 8         24        3         2         NaN          NaN
# 9          1        0         0         NaN          NaN
# 10         1        0         0         NaN          NaN
# 11         1        0         0         NaN          NaN
# 12       4.2        0         0         NaN          NaN
# 13       NaN      NaN       NaN         NaN          NaN
# 14       NaN      NaN       NaN         NaN          NaN
# 15       NaN      NaN       NaN         NaN          NaN
# 16       NaN      NaN       NaN         NaN          NaN
# 17       NaN      NaN       NaN         NaN          NaN
# 18       NaN      NaN       NaN         NaN          NaN
# 19       NaN      NaN       NaN         NaN          NaN
# 20       471       57        16         NaN          NaN
# 21         7       10         0         NaN          NaN
# 22       466       47        11         NaN          NaN
# 23       308        0         5         NaN          NaN
# 24       443       47        11         NaN          NaN
# 25         0        0         0         NaN          NaN
# 26        28        0         0         NaN          NaN
# 27         0        1         0         NaN          NaN
# 28       95%     100%      100%         NaN          NaN
# 0    557,978  335,574   434,937         NaN          NaN
# ..       ...      ...       ...         ...          ...
# 7          1        0         4         NaN          NaN
# 8        998       31       396         NaN          NaN
# 9        NaN      NaN       NaN         NaN          NaN
# 10       NaN      NaN       NaN         NaN          NaN
# 11       NaN      NaN       NaN         NaN          NaN
# 12       NaN      NaN       NaN         NaN          NaN
# 13       NaN      NaN       NaN         NaN          NaN
# 14       NaN      NaN       NaN         NaN          NaN
# 15       NaN      NaN       NaN         NaN          NaN
# 16       NaN      NaN       NaN         NaN          NaN
# 17       NaN      NaN       NaN         NaN          NaN
# 18       NaN      NaN       NaN         NaN          NaN
# 19       NaN      NaN       NaN         NaN          NaN
# 20       NaN      NaN       NaN         NaN          NaN
# 21       NaN      NaN       NaN         NaN          NaN
# 22       NaN      NaN       NaN         NaN          NaN
# 23       NaN      NaN       NaN         NaN          NaN
# 24       NaN      NaN       NaN         NaN          NaN
# 25       NaN      NaN       NaN         NaN          NaN
# 26       NaN      NaN       NaN         NaN          NaN
# 27       NaN      NaN       NaN         NaN          NaN
# 28       NaN      NaN       NaN         NaN          NaN
# 29       NaN      NaN       NaN         NaN          NaN
# 30       NaN      NaN       NaN         NaN          NaN
# 31       NaN      NaN       NaN         NaN          NaN
# 32       NaN      NaN       NaN         NaN          NaN
# 33       NaN      NaN       NaN         NaN          NaN
# 34       NaN      NaN       NaN         NaN          NaN
# 35       NaN      NaN       NaN         NaN          NaN
# 36       NaN      NaN       NaN         NaN          NaN
#
#     Western area combined  Western area rural Western area urban        date  \
# 0                     NaN              263619            1040888  2014-08-12
# 1                     NaN                   0                  0  2014-08-12
# 2                     NaN                   0                  0  2014-08-12
# 3                     NaN                   0                  0  2014-08-12
# 4                     NaN                   0                  0  2014-08-12
# 5                     NaN                   5                 56  2014-08-12
# 6                     NaN                   0                  0  2014-08-12
# 7                     NaN                   0                  1  2014-08-12
# 8                     NaN                   1                 13  2014-08-12
# 9                     NaN                   0                  1  2014-08-12
# 10                    NaN                   0                  1  2014-08-12
# 11                    NaN                   0                  2  2014-08-12
# 12                    NaN                   0               15.4  2014-08-12
# 13                    NaN                 NaN                NaN  2014-08-12
# 14                    NaN                 NaN                NaN  2014-08-12
# 15                    NaN                 NaN                NaN  2014-08-12
# 16                    NaN                 NaN                NaN  2014-08-12
# 17                    NaN                 NaN                NaN  2014-08-12
# 18                    NaN                 NaN                NaN  2014-08-12
# 19                    NaN                 NaN                NaN  2014-08-12
# 20                    NaN                  23                390  2014-08-12
# 21                    NaN                   0                 82  2014-08-12
# 22                    NaN                  23                310  2014-08-12
# 23                    NaN                   0                 25  2014-08-12
# 24                    NaN                  23                103  2014-08-12
# 25                    NaN                   0                  0  2014-08-12
# 26                    NaN                   0                  0  2014-08-12
# 27                    NaN                   0                  6  2014-08-12
# 28                    NaN                100%               101%  2014-08-12
# 0                     NaN             263,619          1,040,888  2014-08-13
# ..                    ...                 ...                ...         ...
# 7                     NaN                   0                  1  2014-12-13
# 8                     NaN                 937               1526  2014-12-13
# 9                     NaN                 NaN                NaN  2014-12-13
# 10                    NaN                 NaN                NaN  2014-12-13
# 11                    NaN                 NaN                NaN  2014-12-13
# 12                    NaN                 NaN                NaN  2014-12-13
# 13                    NaN                 NaN                NaN  2014-12-13
# 14                    NaN                 NaN                NaN  2014-12-13
# 15                    NaN                 NaN                NaN  2014-12-13
# 16                    NaN                 NaN                NaN  2014-12-13
# 17                    NaN                 NaN                NaN  2014-12-13
# 18                    NaN                 NaN                NaN  2014-12-13
# 19                    NaN                 NaN                NaN  2014-12-13
# 20                    NaN                 NaN                NaN  2014-12-13
# 21                    NaN                 NaN                NaN  2014-12-13
# 22                    NaN                 NaN                NaN  2014-12-13
# 23                    NaN                 NaN                NaN  2014-12-13
# 24                    NaN                 NaN                NaN  2014-12-13
# 25                    NaN                 NaN                NaN  2014-12-13
# 26                    NaN                 NaN                NaN  2014-12-13
# 27                    NaN                 NaN                NaN  2014-12-13
# 28                    NaN                 NaN                NaN  2014-12-13
# 29                    NaN                 NaN                NaN  2014-12-13
# 30                    NaN                 NaN                NaN  2014-12-13
# 31                    NaN                 NaN                NaN  2014-12-13
# 32                    NaN                 NaN                NaN  2014-12-13
# 33                    NaN                 NaN                NaN  2014-12-13
# 34                    NaN                 NaN                NaN  2014-12-13
# 35                    NaN                 NaN                NaN  2014-12-13
# 36                    NaN                 NaN                NaN  2014-12-13
#
#                   variable
# 0               population
# 1              new_noncase
# 2            new_suspected
# 3             new_probable
# 4            new_confirmed
# 5              cum_noncase
# 6            cum_suspected
# 7             cum_probable
# 8            cum_confirmed
# 9          death_suspected
# 10          death_probable
# 11         death_confirmed
# 12                     cfr
# 13       etc_new_admission
# 14  etc_currently_admitted
# 15       etc_cum_admission
# 16          etc_new_deaths
# 17          etc_cum_deaths
# 18      etc_new_discharges
# 19      etc_cum_discharges
# 20            cum_contacts
# 21  cum_completed_contacts
# 22       contacts_followed
# 23            new_contacts
# 24        contacts_healthy
# 25            contacts_ill
# 26       contacts_not_seen
# 27  new_completed_contacts
# 28            percent_seen
# 0               population
# ..                     ...
# 7             cum_probable
# 8            cum_confirmed
# 9          death_suspected
# 10          death_probable
# 11         death_confirmed
# 12                     cfr
# 13       etc_new_admission
# 14  etc_currently_admitted
# 15       etc_cum_admission
# 16          etc_new_deaths
# 17          etc_cum_deaths
# 18      etc_new_discharges
# 19      etc_cum_discharges
# 20            cum_contacts
# 21  cum_completed_contacts
# 22       contacts_followed
# 23            new_contacts
# 24        contacts_healthy
# 25            contacts_ill
# 26       contacts_not_seen
# 27  new_completed_contacts
# 28            percent_seen
# 29       total_lab_samples
# 30          repeat_samples
# 31             new_samples
# 32            new_positive
# 33            new_negative
# 34                 pending
# 35         positive_corpse
# 36         negative_corpse
#
# [3262 rows x 27 columns]

# %% [markdown]
# To deal with dates, let's change data type of Dates

# %%
guinea.index.is_unique
# Out:
# False

# %%
guinea_m = guinea.copy()
new_ind = guinea.Date + guinea.Description
guinea_m.index = new_ind
guinea_m.head()
# Out:
#                                             Beyla Boffa Conakry Coyah Dabola  \
# 2014-08-04New cases of suspects               NaN     0       5   NaN      0
# 2014-08-04New cases of probables              NaN     0       0   NaN      0
# 2014-08-04New cases of confirmed              NaN     0       1   NaN      0
# 2014-08-04Total new cases registered so far   NaN     0       6   NaN      0
# 2014-08-04Total cases of suspects             NaN     0       9   NaN      0
#
#                                             Dalaba        Date  \
# 2014-08-04New cases of suspects                NaN  2014-08-04
# 2014-08-04New cases of probables               NaN  2014-08-04
# 2014-08-04New cases of confirmed               NaN  2014-08-04
# 2014-08-04Total new cases registered so far    NaN  2014-08-04
# 2014-08-04Total cases of suspects              NaN  2014-08-04
#
#                                                                    Description  \
# 2014-08-04New cases of suspects                          New cases of suspects
# 2014-08-04New cases of probables                        New cases of probables
# 2014-08-04New cases of confirmed                        New cases of confirmed
# 2014-08-04Total new cases registered so far  Total new cases registered so far
# 2014-08-04Total cases of suspects                      Total cases of suspects
#
#                                             Dinguiraye Dubreka  ...  Lola  \
# 2014-08-04New cases of suspects                      0       0  ...   NaN
# 2014-08-04New cases of probables                     0       0  ...   NaN
# 2014-08-04New cases of confirmed                     0       0  ...   NaN
# 2014-08-04Total new cases registered so far          0       0  ...   NaN
# 2014-08-04Total cases of suspects                    0       0  ...   NaN
#
#                                             Macenta Mzerekore Nzerekore Pita  \
# 2014-08-04New cases of suspects                   0       NaN         0    0
# 2014-08-04New cases of probables                  0       NaN         0    0
# 2014-08-04New cases of confirmed                  0       NaN         0    0
# 2014-08-04Total new cases registered so far       0       NaN         0    0
# 2014-08-04Total cases of suspects                 0       NaN         0    0
#
#                                             Siguiri Telimele Totals Yomou  \
# 2014-08-04New cases of suspects                   0        0      5   NaN
# 2014-08-04New cases of probables                  0        0      0   NaN
# 2014-08-04New cases of confirmed                  0        0      4   NaN
# 2014-08-04Total new cases registered so far       0        0      9   NaN
# 2014-08-04Total cases of suspects                 0        0     11   NaN
#
#                                             Month
# 2014-08-04New cases of suspects                 8
# 2014-08-04New cases of probables                8
# 2014-08-04New cases of confirmed                8
# 2014-08-04Total new cases registered so far     8
# 2014-08-04Total cases of suspects               8
#
# [5 rows x 26 columns]

# %%
guinea_m['Date'][0].day
# Out:
# 4

# %%
type(guinea['Date'][0])
# Out:
# pandas.core.series.Series

# %%
guinea_m['Month'] = pd.DatetimeIndex(guinea_m['Date']).month

# %%
guinea_m
# Out:
#                                                    Beyla Boffa Conakry Coyah  \
# 2014-08-04New cases of suspects                      NaN     0       5   NaN
# 2014-08-04New cases of probables                     NaN     0       0   NaN
# 2014-08-04New cases of confirmed                     NaN     0       1   NaN
# 2014-08-04Total new cases registered so far          NaN     0       6   NaN
# 2014-08-04Total cases of suspects                    NaN     0       9   NaN
# 2014-08-04Total cases of probables                   NaN     5       8   NaN
# 2014-08-04Total cases of confirmed                   NaN    18      78   NaN
# 2014-08-04Cumulative (confirmed + probable + su...   NaN    23      95   NaN
# 2014-08-04New deaths registered today                NaN     0       0   NaN
# 2014-08-04New deaths registered today (confirmed)    NaN     0       0   NaN
# 2014-08-04New deaths registered today (probables)    NaN     0       0   NaN
# 2014-08-04New deaths registered today (suspects)     NaN     0       0   NaN
# 2014-08-04Total deaths of suspects                   NaN     0       2   NaN
# 2014-08-04Total deaths of probables                  NaN     5       8   NaN
# 2014-08-04Total deaths of confirmed                  NaN    11      32   NaN
# 2014-08-04Total deaths (confirmed + probables +...   NaN    16      42   NaN
# 2014-08-04Total PEC center today                     NaN     0      21   NaN
# 2014-08-04Total PEC center today (confirmed)         NaN     0      10   NaN
# 2014-08-04Total PEC center today (probables)         NaN     0       0   NaN
# 2014-08-04Total PEC center today (suspects)          NaN     0      11   NaN
# 2014-08-04Total of deaths in confirmed cases in...   NaN     6      20   NaN
# 2014-08-04Total of cured in confirmed cases in CTE   NaN     7      34   NaN
# 2014-08-04Number of male confirmed cases             NaN    10      48   NaN
# 2014-08-04Number of female confirmed cases           NaN     8      30   NaN
# 2014-08-04Number of male probables cases             NaN     3       4   NaN
# 2014-08-04Number of female probables cases           NaN     2       4   NaN
# 2014-08-04Number of male suspects cases              NaN     0       5   NaN
# 2014-08-04Number of female suspects cases            NaN     0       4   NaN
# 2014-08-04Total number of male cases                 NaN    13      57   NaN
# 2014-08-04Total number of female cases               NaN    10      38   NaN
# ...                                                  ...   ...     ...   ...
# 2014-10-01New cases of confirmed                     NaN   NaN       2   NaN
# 2014-10-01Total new cases registered so far            0     0      17     0
# 2014-10-01Total cases of suspects                      0     0      19     0
# 2014-10-01Total cases of probables                     0     5      10     0
# 2014-10-01Total cases of confirmed                     2    19     170    12
# 2014-10-01Cumulative (confirmed + probable + su...     2    24     199    12
# 2014-10-01Total suspected non-class cases              0    20     355     6
# 2014-10-01New deaths registered                      NaN   NaN     NaN   NaN
# 2014-10-01Total deaths of suspects                     0     0       0     0
# 2014-10-01Total deaths of probables                    0     5      10     0
# 2014-10-01Total deaths of confirmed                    1    11      68     5
# 2014-10-01Total deaths (confirmed + probables +...     0    16      78     5
# 2014-10-01Fatality rate for confirmed and proba...  100%   67%     39%   42%
# 2014-10-01New cases of confirmed among health w...   NaN   NaN       2   NaN
# 2014-10-01Total case of confirmed among health ...     0     0      40     1
# 2014-10-01New deaths registered among health wo...     0     0       0     0
# 2014-10-01Total deaths registered among health ...     0     0      18     0
# 2014-10-01New admits to CTE so far                   NaN   NaN      15   NaN
# 2014-10-01Total number of hospitalized cases in...     0     0      48     0
# 2014-10-01Total number of exits from CTE               0     0       9     0
# 2014-10-01Total number of admissions to CTE            0     0     571     0
# 2014-10-01New contacts registered so far             NaN   NaN     NaN   NaN
# 2014-10-01Total contacts registered from start ...     2   397    3319   116
# 2014-10-01Number of contacts to follow today         929     0     825    98
# 2014-10-01Number of contacts followed today           29     0     778    98
# 2014-10-01Number of contacts out of the track 2...     0   397    2494    17
# 2014-10-01Number of contacts lost to follow up         0     0       0     1
# 2014-10-01Number of samples collected today          NaN   NaN      16   NaN
# 2014-10-01Number of samples under test               NaN   NaN       0   NaN
# 2014-10-01Total samples tested                       NaN   NaN    1171   NaN
#
#                                                    Dabola Dalaba       Date  \
# 2014-08-04New cases of suspects                         0    NaN 2014-08-04
# 2014-08-04New cases of probables                        0    NaN 2014-08-04
# 2014-08-04New cases of confirmed                        0    NaN 2014-08-04
# 2014-08-04Total new cases registered so far             0    NaN 2014-08-04
# 2014-08-04Total cases of suspects                       0    NaN 2014-08-04
# 2014-08-04Total cases of probables                      3    NaN 2014-08-04
# 2014-08-04Total cases of confirmed                      1    NaN 2014-08-04
# 2014-08-04Cumulative (confirmed + probable + su...      4    NaN 2014-08-04
# 2014-08-04New deaths registered today                   0    NaN 2014-08-04
# 2014-08-04New deaths registered today (confirmed)       0    NaN 2014-08-04
# 2014-08-04New deaths registered today (probables)       0    NaN 2014-08-04
# 2014-08-04New deaths registered today (suspects)        0    NaN 2014-08-04
# 2014-08-04Total deaths of suspects                      0    NaN 2014-08-04
# 2014-08-04Total deaths of probables                     3    NaN 2014-08-04
# 2014-08-04Total deaths of confirmed                     1    NaN 2014-08-04
# 2014-08-04Total deaths (confirmed + probables +...      4    NaN 2014-08-04
# 2014-08-04Total PEC center today                        0    NaN 2014-08-04
# 2014-08-04Total PEC center today (confirmed)            0    NaN 2014-08-04
# 2014-08-04Total PEC center today (probables)            0    NaN 2014-08-04
# 2014-08-04Total PEC center today (suspects)             0    NaN 2014-08-04
# 2014-08-04Total of deaths in confirmed cases in...      0    NaN 2014-08-04
# 2014-08-04Total of cured in confirmed cases in CTE      0    NaN 2014-08-04
# 2014-08-04Number of male confirmed cases                1    NaN 2014-08-04
# 2014-08-04Number of female confirmed cases              0    NaN 2014-08-04
# 2014-08-04Number of male probables cases                1    NaN 2014-08-04
# 2014-08-04Number of female probables cases              2    NaN 2014-08-04
# 2014-08-04Number of male suspects cases                 0    NaN 2014-08-04
# 2014-08-04Number of female suspects cases               0    NaN 2014-08-04
# 2014-08-04Total number of male cases                    2    NaN 2014-08-04
# 2014-08-04Total number of female cases                  2    NaN 2014-08-04
# ...                                                   ...    ...        ...
# 2014-10-01New cases of confirmed                      NaN    NaN 2014-10-01
# 2014-10-01Total new cases registered so far             0      0 2014-10-01
# 2014-10-01Total cases of suspects                       0      0 2014-10-01
# 2014-10-01Total cases of probables                      3      0 2014-10-01
# 2014-10-01Total cases of confirmed                      1      6 2014-10-01
# 2014-10-01Cumulative (confirmed + probable + su...      4      6 2014-10-01
# 2014-10-01Total suspected non-class cases               3      1 2014-10-01
# 2014-10-01New deaths registered                       NaN    NaN 2014-10-01
# 2014-10-01Total deaths of suspects                      0      0 2014-10-01
# 2014-10-01Total deaths of probables                     3      0 2014-10-01
# 2014-10-01Total deaths of confirmed                     1      0 2014-10-01
# 2014-10-01Total deaths (confirmed + probables +...      4      0 2014-10-01
# 2014-10-01Fatality rate for confirmed and proba...   100%     0% 2014-10-01
# 2014-10-01New cases of confirmed among health w...    NaN    NaN 2014-10-01
# 2014-10-01Total case of confirmed among health ...      0      0 2014-10-01
# 2014-10-01New deaths registered among health wo...      0      0 2014-10-01
# 2014-10-01Total deaths registered among health ...      0      0 2014-10-01
# 2014-10-01New admits to CTE so far                    NaN    NaN 2014-10-01
# 2014-10-01Total number of hospitalized cases in...      0      0 2014-10-01
# 2014-10-01Total number of exits from CTE                0      0 2014-10-01
# 2014-10-01Total number of admissions to CTE             0      0 2014-10-01
# 2014-10-01New contacts registered so far              NaN    NaN 2014-10-01
# 2014-10-01Total contacts registered from start ...     69     34 2014-10-01
# 2014-10-01Number of contacts to follow today            0     34 2014-10-01
# 2014-10-01Number of contacts followed today             0     20 2014-10-01
# 2014-10-01Number of contacts out of the track 2...     69      0 2014-10-01
# 2014-10-01Number of contacts lost to follow up          0      0 2014-10-01
# 2014-10-01Number of samples collected today           NaN    NaN 2014-10-01
# 2014-10-01Number of samples under test                NaN    NaN 2014-10-01
# 2014-10-01Total samples tested                        NaN    NaN 2014-10-01
#
#                                                                                         Description  \
# 2014-08-04New cases of suspects                                               New cases of suspects
# 2014-08-04New cases of probables                                             New cases of probables
# 2014-08-04New cases of confirmed                                             New cases of confirmed
# 2014-08-04Total new cases registered so far                       Total new cases registered so far
# 2014-08-04Total cases of suspects                                           Total cases of suspects
# 2014-08-04Total cases of probables                                         Total cases of probables
# 2014-08-04Total cases of confirmed                                         Total cases of confirmed
# 2014-08-04Cumulative (confirmed + probable + su...     Cumulative (confirmed + probable + suspects)
# 2014-08-04New deaths registered today                                   New deaths registered today
# 2014-08-04New deaths registered today (confirmed)           New deaths registered today (confirmed)
# 2014-08-04New deaths registered today (probables)           New deaths registered today (probables)
# 2014-08-04New deaths registered today (suspects)             New deaths registered today (suspects)
# 2014-08-04Total deaths of suspects                                         Total deaths of suspects
# 2014-08-04Total deaths of probables                                       Total deaths of probables
# 2014-08-04Total deaths of confirmed                                       Total deaths of confirmed
# 2014-08-04Total deaths (confirmed + probables +...  Total deaths (confirmed + probables + suspects)
# 2014-08-04Total PEC center today                                             Total PEC center today
# 2014-08-04Total PEC center today (confirmed)                     Total PEC center today (confirmed)
# 2014-08-04Total PEC center today (probables)                     Total PEC center today (probables)
# 2014-08-04Total PEC center today (suspects)                       Total PEC center today (suspects)
# 2014-08-04Total of deaths in confirmed cases in...        Total of deaths in confirmed cases in CTE
# 2014-08-04Total of cured in confirmed cases in CTE         Total of cured in confirmed cases in CTE
# 2014-08-04Number of male confirmed cases                             Number of male confirmed cases
# 2014-08-04Number of female confirmed cases                         Number of female confirmed cases
# 2014-08-04Number of male probables cases                             Number of male probables cases
# 2014-08-04Number of female probables cases                         Number of female probables cases
# 2014-08-04Number of male suspects cases                               Number of male suspects cases
# 2014-08-04Number of female suspects cases                           Number of female suspects cases
# 2014-08-04Total number of male cases                                     Total number of male cases
# 2014-08-04Total number of female cases                                 Total number of female cases
# ...                                                                                             ...
# 2014-10-01New cases of confirmed                                             New cases of confirmed
# 2014-10-01Total new cases registered so far                       Total new cases registered so far
# 2014-10-01Total cases of suspects                                           Total cases of suspects
# 2014-10-01Total cases of probables                                         Total cases of probables
# 2014-10-01Total cases of confirmed                                         Total cases of confirmed
# 2014-10-01Cumulative (confirmed + probable + su...     Cumulative (confirmed + probable + suspects)
# 2014-10-01Total suspected non-class cases                           Total suspected non-class cases
# 2014-10-01New deaths registered                                               New deaths registered
# 2014-10-01Total deaths of suspects                                         Total deaths of suspects
# 2014-10-01Total deaths of probables                                       Total deaths of probables
# 2014-10-01Total deaths of confirmed                                       Total deaths of confirmed
# 2014-10-01Total deaths (confirmed + probables +...  Total deaths (confirmed + probables + suspects)
# 2014-10-01Fatality rate for confirmed and proba...        Fatality rate for confirmed and probables
# 2014-10-01New cases of confirmed among health w...      New cases of confirmed among health workers
# 2014-10-01Total case of confirmed among health ...     Total case of confirmed among health workers
# 2014-10-01New deaths registered among health wo...       New deaths registered among health workers
# 2014-10-01Total deaths registered among health ...     Total deaths registered among health workers
# 2014-10-01New admits to CTE so far                                         New admits to CTE so far
# 2014-10-01Total number of hospitalized cases in...        Total number of hospitalized cases in CTE
# 2014-10-01Total number of exits from CTE                             Total number of exits from CTE
# 2014-10-01Total number of admissions to CTE                       Total number of admissions to CTE
# 2014-10-01New contacts registered so far                             New contacts registered so far
# 2014-10-01Total contacts registered from start ...        Total contacts registered from start date
# 2014-10-01Number of contacts to follow today                     Number of contacts to follow today
# 2014-10-01Number of contacts followed today                       Number of contacts followed today
# 2014-10-01Number of contacts out of the track 2...      Number of contacts out of the track 21 days
# 2014-10-01Number of contacts lost to follow up                 Number of contacts lost to follow up
# 2014-10-01Number of samples collected today                       Number of samples collected today
# 2014-10-01Number of samples under test                                 Number of samples under test
# 2014-10-01Total samples tested                                                 Total samples tested
#
#                                                    Dinguiraye Dubreka  ...   \
# 2014-08-04New cases of suspects                             0       0  ...
# 2014-08-04New cases of probables                            0       0  ...
# 2014-08-04New cases of confirmed                            0       0  ...
# 2014-08-04Total new cases registered so far                 0       0  ...
# 2014-08-04Total cases of suspects                           0       0  ...
# 2014-08-04Total cases of probables                          1       0  ...
# 2014-08-04Total cases of confirmed                          0       0  ...
# 2014-08-04Cumulative (confirmed + probable + su...          1       0  ...
# 2014-08-04New deaths registered today                       0       0  ...
# 2014-08-04New deaths registered today (confirmed)           0       0  ...
# 2014-08-04New deaths registered today (probables)           0       0  ...
# 2014-08-04New deaths registered today (suspects)            0       0  ...
# 2014-08-04Total deaths of suspects                          0       0  ...
# 2014-08-04Total deaths of probables                         1       0  ...
# 2014-08-04Total deaths of confirmed                         0       0  ...
# 2014-08-04Total deaths (confirmed + probables +...          1       0  ...
# 2014-08-04Total PEC center today                            0       0  ...
# 2014-08-04Total PEC center today (confirmed)                0       0  ...
# 2014-08-04Total PEC center today (probables)                0       0  ...
# 2014-08-04Total PEC center today (suspects)                 0       0  ...
# 2014-08-04Total of deaths in confirmed cases in...          0       0  ...
# 2014-08-04Total of cured in confirmed cases in CTE          0       0  ...
# 2014-08-04Number of male confirmed cases                    0       0  ...
# 2014-08-04Number of female confirmed cases                  0       0  ...
# 2014-08-04Number of male probables cases                    0       0  ...
# 2014-08-04Number of female probables cases                  1       0  ...
# 2014-08-04Number of male suspects cases                     0       0  ...
# 2014-08-04Number of female suspects cases                   0       0  ...
# 2014-08-04Total number of male cases                        0       0  ...
# 2014-08-04Total number of female cases                      1       0  ...
# ...                                                       ...     ...  ...
# 2014-10-01New cases of confirmed                          NaN     NaN  ...
# 2014-10-01Total new cases registered so far                 0       0  ...
# 2014-10-01Total cases of suspects                           0       0  ...
# 2014-10-01Total cases of probables                          1       0  ...
# 2014-10-01Total cases of confirmed                          0      21  ...
# 2014-10-01Cumulative (confirmed + probable + su...          1      21  ...
# 2014-10-01Total suspected non-class cases                   0      20  ...
# 2014-10-01New deaths registered                           NaN     NaN  ...
# 2014-10-01Total deaths of suspects                          0       0  ...
# 2014-10-01Total deaths of probables                         1       0  ...
# 2014-10-01Total deaths of confirmed                         0       7  ...
# 2014-10-01Total deaths (confirmed + probables +...          1       7  ...
# 2014-10-01Fatality rate for confirmed and proba...       100%     33%  ...
# 2014-10-01New cases of confirmed among health w...        NaN     NaN  ...
# 2014-10-01Total case of confirmed among health ...          0       3  ...
# 2014-10-01New deaths registered among health wo...          0       0  ...
# 2014-10-01Total deaths registered among health ...          0       1  ...
# 2014-10-01New admits to CTE so far                        NaN     NaN  ...
# 2014-10-01Total number of hospitalized cases in...          0       0  ...
# 2014-10-01Total number of exits from CTE                    0       0  ...
# 2014-10-01Total number of admissions to CTE                 0       0  ...
# 2014-10-01New contacts registered so far                  NaN     NaN  ...
# 2014-10-01Total contacts registered from start ...          0     341  ...
# 2014-10-01Number of contacts to follow today                0      49  ...
# 2014-10-01Number of contacts followed today                 0      49  ...
# 2014-10-01Number of contacts out of the track 2...          0     292  ...
# 2014-10-01Number of contacts lost to follow up              0       0  ...
# 2014-10-01Number of samples collected today               NaN     NaN  ...
# 2014-10-01Number of samples under test                    NaN     NaN  ...
# 2014-10-01Total samples tested                            NaN     NaN  ...
#
#                                                     Lola Macenta Mzerekore  \
# 2014-08-04New cases of suspects                      NaN       0       NaN
# 2014-08-04New cases of probables                     NaN       0       NaN
# 2014-08-04New cases of confirmed                     NaN       0       NaN
# 2014-08-04Total new cases registered so far          NaN       0       NaN
# 2014-08-04Total cases of suspects                    NaN       0       NaN
# 2014-08-04Total cases of probables                   NaN      11       NaN
# 2014-08-04Total cases of confirmed                   NaN      28       NaN
# 2014-08-04Cumulative (confirmed + probable + su...   NaN      39       NaN
# 2014-08-04New deaths registered today                NaN       0       NaN
# 2014-08-04New deaths registered today (confirmed)    NaN       0       NaN
# 2014-08-04New deaths registered today (probables)    NaN       0       NaN
# 2014-08-04New deaths registered today (suspects)     NaN       0       NaN
# 2014-08-04Total deaths of suspects                   NaN       0       NaN
# 2014-08-04Total deaths of probables                  NaN      11       NaN
# 2014-08-04Total deaths of confirmed                  NaN      18       NaN
# 2014-08-04Total deaths (confirmed + probables +...   NaN      29       NaN
# 2014-08-04Total PEC center today                     NaN       0       NaN
# 2014-08-04Total PEC center today (confirmed)         NaN       0       NaN
# 2014-08-04Total PEC center today (probables)         NaN       0       NaN
# 2014-08-04Total PEC center today (suspects)          NaN       0       NaN
# 2014-08-04Total of deaths in confirmed cases in...   NaN      10       NaN
# 2014-08-04Total of cured in confirmed cases in CTE   NaN       8       NaN
# 2014-08-04Number of male confirmed cases             NaN      14       NaN
# 2014-08-04Number of female confirmed cases           NaN      14       NaN
# 2014-08-04Number of male probables cases             NaN       5       NaN
# 2014-08-04Number of female probables cases           NaN       6       NaN
# 2014-08-04Number of male suspects cases              NaN       0       NaN
# 2014-08-04Number of female suspects cases            NaN       0       NaN
# 2014-08-04Total number of male cases                 NaN      19       NaN
# 2014-08-04Total number of female cases               NaN      20       NaN
# ...                                                  ...     ...       ...
# 2014-10-01New cases of confirmed                     NaN       2       NaN
# 2014-10-01Total new cases registered so far            9       5       NaN
# 2014-10-01Total cases of suspects                      9       9       NaN
# 2014-10-01Total cases of probables                     0      16       NaN
# 2014-10-01Total cases of confirmed                     2     378       NaN
# 2014-10-01Cumulative (confirmed + probable + su...    11     403       NaN
# 2014-10-01Total suspected non-class cases              4     197       NaN
# 2014-10-01New deaths registered                      NaN      15       NaN
# 2014-10-01Total deaths of suspects                     0       0       NaN
# 2014-10-01Total deaths of probables                    0      16       NaN
# 2014-10-01Total deaths of confirmed                    2     230       NaN
# 2014-10-01Total deaths (confirmed + probables +...     0     246       NaN
# 2014-10-01Fatality rate for confirmed and proba...  100%     61%       NaN
# 2014-10-01New cases of confirmed among health w...   NaN     NaN       NaN
# 2014-10-01Total case of confirmed among health ...     0       9       NaN
# 2014-10-01New deaths registered among health wo...     0       0       NaN
# 2014-10-01Total deaths registered among health ...     0       7       NaN
# 2014-10-01New admits to CTE so far                   NaN     NaN       NaN
# 2014-10-01Total number of hospitalized cases in...   NaN      12       NaN
# 2014-10-01Total number of exits from CTE             NaN      15       NaN
# 2014-10-01Total number of admissions to CTE          NaN      27       NaN
# 2014-10-01New contacts registered so far             NaN     NaN       NaN
# 2014-10-01Total contacts registered from start ...     0    1563       NaN
# 2014-10-01Number of contacts to follow today           0    1038       NaN
# 2014-10-01Number of contacts followed today            0    1038       NaN
# 2014-10-01Number of contacts out of the track 2...     0     525       NaN
# 2014-10-01Number of contacts lost to follow up         0       0       NaN
# 2014-10-01Number of samples collected today          NaN       0       NaN
# 2014-10-01Number of samples under test               NaN       0       NaN
# 2014-10-01Total samples tested                       NaN       0       NaN
#
#                                                    Nzerekore Pita Siguiri  \
# 2014-08-04New cases of suspects                            0    0       0
# 2014-08-04New cases of probables                           0    0       0
# 2014-08-04New cases of confirmed                           0    0       0
# 2014-08-04Total new cases registered so far                0    0       0
# 2014-08-04Total cases of suspects                          0    0       0
# 2014-08-04Total cases of probables                         0    1       0
# 2014-08-04Total cases of confirmed                         4    1       6
# 2014-08-04Cumulative (confirmed + probable + su...         4    2       6
# 2014-08-04New deaths registered today                      0    0       0
# 2014-08-04New deaths registered today (confirmed)          0    0       0
# 2014-08-04New deaths registered today (probables)          0    0       0
# 2014-08-04New deaths registered today (suspects)           0    0       0
# 2014-08-04Total deaths of suspects                         0    0       0
# 2014-08-04Total deaths of probables                        0    1       0
# 2014-08-04Total deaths of confirmed                        1    1       3
# 2014-08-04Total deaths (confirmed + probables +...         1    2       3
# 2014-08-04Total PEC center today                           0    0       2
# 2014-08-04Total PEC center today (confirmed)               0    0       2
# 2014-08-04Total PEC center today (probables)               0    0       0
# 2014-08-04Total PEC center today (suspects)                0    0       0
# 2014-08-04Total of deaths in confirmed cases in...         0    0       2
# 2014-08-04Total of cured in confirmed cases in CTE         0    0       0
# 2014-08-04Number of male confirmed cases                   2    0       6
# 2014-08-04Number of female confirmed cases                 2    1       0
# 2014-08-04Number of male probables cases                   0    1       0
# 2014-08-04Number of female probables cases                 0    0       0
# 2014-08-04Number of male suspects cases                    0    0       2
# 2014-08-04Number of female suspects cases                  0    0       0
# 2014-08-04Total number of male cases                       2    1       8
# 2014-08-04Total number of female cases                     2    1       0
# ...                                                      ...  ...     ...
# 2014-10-01New cases of confirmed                         NaN  NaN     NaN
# 2014-10-01Total new cases registered so far                1    0       0
# 2014-10-01Total cases of suspects                          2    1       0
# 2014-10-01Total cases of probables                        17    1       0
# 2014-10-01Total cases of confirmed                        31    6       6
# 2014-10-01Cumulative (confirmed + probable + su...        50    8       6
# 2014-10-01Total suspected non-class cases                 16   18       9
# 2014-10-01New deaths registered                          NaN  NaN     NaN
# 2014-10-01Total deaths of suspects                         0    0       0
# 2014-10-01Total deaths of probables                       17    1       0
# 2014-10-01Total deaths of confirmed                       15    2       3
# 2014-10-01Total deaths (confirmed + probables +...        32    3       3
# 2014-10-01Fatality rate for confirmed and proba...       64%  38%     50%
# 2014-10-01New cases of confirmed among health w...       NaN  NaN     NaN
# 2014-10-01Total case of confirmed among health ...         2    0       2
# 2014-10-01New deaths registered among health wo...         0    0       0
# 2014-10-01Total deaths registered among health ...         1    0       0
# 2014-10-01New admits to CTE so far                       NaN  NaN     NaN
# 2014-10-01Total number of hospitalized cases in...         0    0       0
# 2014-10-01Total number of exits from CTE                   0    0       0
# 2014-10-01Total number of admissions to CTE                0    0      13
# 2014-10-01New contacts registered so far                 NaN  NaN     NaN
# 2014-10-01Total contacts registered from start ...       353  140     141
# 2014-10-01Number of contacts to follow today             126    0       0
# 2014-10-01Number of contacts followed today              126    0       0
# 2014-10-01Number of contacts out of the track 2...       227  140     141
# 2014-10-01Number of contacts lost to follow up             0    0       0
# 2014-10-01Number of samples collected today              NaN  NaN     NaN
# 2014-10-01Number of samples under test                   NaN  NaN     NaN
# 2014-10-01Total samples tested                           NaN  NaN     NaN
#
#                                                    Telimele Totals Yomou Month
# 2014-08-04New cases of suspects                           0      5   NaN     8
# 2014-08-04New cases of probables                          0      0   NaN     8
# 2014-08-04New cases of confirmed                          0      4   NaN     8
# 2014-08-04Total new cases registered so far               0      9   NaN     8
# 2014-08-04Total cases of suspects                         0     11   NaN     8
# 2014-08-04Total cases of probables                        3    133   NaN     8
# 2014-08-04Total cases of confirmed                       23    351   NaN     8
# 2014-08-04Cumulative (confirmed + probable + su...       26    495   NaN     8
# 2014-08-04New deaths registered today                     0      2   NaN     8
# 2014-08-04New deaths registered today (confirmed)         0      2   NaN     8
# 2014-08-04New deaths registered today (probables)         0      0   NaN     8
# 2014-08-04New deaths registered today (suspects)          0      0   NaN     8
# 2014-08-04Total deaths of suspects                        0      2   NaN     8
# 2014-08-04Total deaths of probables                       3    133   NaN     8
# 2014-08-04Total deaths of confirmed                       7    228   NaN     8
# 2014-08-04Total deaths (confirmed + probables +...       10    363   NaN     8
# 2014-08-04Total PEC center today                          0     31   NaN     8
# 2014-08-04Total PEC center today (confirmed)              0     18   NaN     8
# 2014-08-04Total PEC center today (probables)              0      0   NaN     8
# 2014-08-04Total PEC center today (suspects)               0     13   NaN     8
# 2014-08-04Total of deaths in confirmed cases in...        5    138   NaN     8
# 2014-08-04Total of cured in confirmed cases in CTE        9     89   NaN     8
# 2014-08-04Number of male confirmed cases                  6    161   NaN     8
# 2014-08-04Number of female confirmed cases               17    190   NaN     8
# 2014-08-04Number of male probables cases                  1     52   NaN     8
# 2014-08-04Number of female probables cases                2     81   NaN     8
# 2014-08-04Number of male suspects cases                   0      7   NaN     8
# 2014-08-04Number of female suspects cases                 0      6   NaN     8
# 2014-08-04Total number of male cases                      7    220   NaN     8
# 2014-08-04Total number of female cases                   19    277   NaN     8
# ...                                                     ...    ...   ...   ...
# 2014-10-01New cases of confirmed                        NaN      6   NaN    10
# 2014-10-01Total new cases registered so far               0     34     0    10
# 2014-10-01Total cases of suspects                         0     45     0    10
# 2014-10-01Total cases of probables                        3    177     0    10
# 2014-10-01Total cases of confirmed                       23    977    11    10
# 2014-10-01Cumulative (confirmed + probable + su...       26   1199    11    10
# 2014-10-01Total suspected non-class cases                18    974     4    10
# 2014-10-01New deaths registered                         NaN     15   NaN    10
# 2014-10-01Total deaths of suspects                        0      0     0    10
# 2014-10-01Total deaths of probables                       3    177     0    10
# 2014-10-01Total deaths of confirmed                       7    562     5    10
# 2014-10-01Total deaths (confirmed + probables +...       10    739     5    10
# 2014-10-01Fatality rate for confirmed and proba...      38%    62%   45%    10
# 2014-10-01New cases of confirmed among health w...      NaN      2   NaN    10
# 2014-10-01Total case of confirmed among health ...        2     69     1    10
# 2014-10-01New deaths registered among health wo...        0      0     0    10
# 2014-10-01Total deaths registered among health ...        1     35     1    10
# 2014-10-01New admits to CTE so far                      NaN     25   NaN    10
# 2014-10-01Total number of hospitalized cases in...        0    114     0    10
# 2014-10-01Total number of exits from CTE                  0     29     0    10
# 2014-10-01Total number of admissions to CTE              41   1576     0    10
# 2014-10-01New contacts registered so far                NaN      0   NaN    10
# 2014-10-01Total contacts registered from start ...      259  11772    56    10
# 2014-10-01Number of contacts to follow today              0   2661     0    10
# 2014-10-01Number of contacts followed today               0   2595     0    10
# 2014-10-01Number of contacts out of the track 2...      259   9110    56    10
# 2014-10-01Number of contacts lost to follow up            0      1     0    10
# 2014-10-01Number of samples collected today             NaN     25   NaN    10
# 2014-10-01Number of samples under test                  NaN      0   NaN    10
# 2014-10-01Total samples tested                          NaN   2832   NaN    10
#
# [714 rows x 26 columns]

# %%
guinea.Description.unique()

# %% [markdown]
# ## Task 2. RNA Sequences
#
# In the `DATA_FOLDER/microbiome` subdirectory, there are 9 spreadsheets of microbiome data that was acquired from high-throughput RNA sequencing procedures, along with a 10<sup>th</sup> file that describes the content of each.
#
# Use pandas to import the first 9 spreadsheets into a single `DataFrame`.
# Then, add the metadata information from the 10<sup>th</sup> spreadsheet as columns in the combined `DataFrame`.
# Make sure that the final `DataFrame` has a unique index and all the `NaN` values have been replaced by the tag `unknown`.

# %%
# Write your answer here

# %% [markdown]
# ## Task 3. Class War in Titanic
#
# Use pandas to import the data file `Data/titanic.xls`. It contains data on all the passengers that travelled on the Titanic.

# %%
from IPython.core.display import HTML
HTML(filename=DATA_FOLDER+'/titanic.html')

# %% [markdown]
# For each of the following questions state clearly your assumptions and discuss your findings:
# 1. Describe the *type* and the *value range* of each attribute. Indicate and transform the attributes that can be `Categorical`.
# 2. Plot histograms for the *travel class*, *embarkation port*, *sex* and *age* attributes. For the latter one, use *discrete decade intervals*.
# 3. Calculate the proportion of passengers by *cabin floor*. Present your results in a *pie chart*.
# 4. For each *travel class*, calculate the proportion of the passengers that survived. Present your results in *pie charts*.
# 5. Calculate the proportion of the passengers that survived by *travel class* and *sex*. Present your results in *a single histogram*.
# 6. Create 2 equally populated *age categories* and calculate survival proportions by *age category*, *travel class* and *sex*. Present your results in a `DataFrame` with unique index.

# %%
# Write your answer here
